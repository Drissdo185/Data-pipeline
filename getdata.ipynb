# %%
##  API:WJJZXNDW90WF0ET0 
import requests
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=WJJZXNDW90WF0ET0'
r = requests.get(url)
data = r.json()
print(data)
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'IBM', '3. Last Refreshed': '2023-08-08 19:55:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2023-08-08 19:55:00': {'1. open': '146.0000', '2. high': '146.0000', '3. low': '145.9300', '4. close': '146.0000', '5. volume': '16'}, '2023-08-08 19:50:00': {'1. open': '146.0000', '2. high': '146.0000', '3. low': '146.0000', '4. close': '146.0000', '5. volume': '156'}, '2023-08-08 19:45:00': {'1. open': '146.0000', '2. high': '146.0900', '3. low': '146.0000', '4. close': '146.0600', '5. volume': '96'}, '2023-08-08 19:40:00': {'1. open': '145.9400', '2. high': '146.0100', '3. low': '145.9400', '4. close': '146.0000', '5. volume': '9'}, '2023-08-08 19:30:00': {'1. open': '145.9500', '2. high': '146.0200', '3. low': '145.9300', '4. close': '145.9300', '5. volume': '503'}, '2023-08-08 19:20:00': {'1. open': '145.9300', '2. hig
# ...

# %%
import pandas as pd
import json
from pandas import json_normaliz
df = json_normalize(data)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\T. Dat\Desktop\DataPipline\getdata.ipynb Cell 2 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/T.%20Dat/Desktop/DataPipline/getdata.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/T.%20Dat/Desktop/DataPipline/getdata.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import json
# ----> <a href='vscode-notebook-cell:/c%3A/Users/T.%20Dat/Desktop/DataPipline/getdata.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> from pandas import json_normaliz
#       <a href='vscode-notebook-cell:/c%3A/Users/T.%20Dat/Desktop/DataPipline/getdata.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> df = json_normalize(data)
#
# ImportError: cannot import name 'json_normaliz' from 'pandas' (c:\Users\T. Dat\anaconda3\lib\site-packages\pandas\__init__.py)
